# %% [markdown]
# # Cannabis Data Scraping

# %%
#Dependencies
from bs4 import BeautifulSoup
from splinter import Browser
from pprint import pprint
import pymongo
import pandas as pd
import requests

# %%
browser = Browser('chrome')
browser.visit('https://disa.com/map-of-marijuana-legality-by-state/')        
html_doc = browser.html

# %%
r = requests.get('https://disa.com/map-of-marijuana-legality-by-state/')
soup = BeautifulSoup(r.text, 'html.parser') 

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://disa.com/" rel="home"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="white" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="yes" name="apple-touch-fullscreen">
#    <link href="/public/ui/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#    <link href="/public/ui/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="/public/ui/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="/public/ui/favicons/manifest.json" rel="manifest"/>
#    <link color="#ffffff" href="/public/ui/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#    <link href="/public/ui/favicons/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# # Cleaning up data

# %%
items=soup.find_all('div',class_='isotope-item')
print(items)
# Out:
# [<div class="isotope-item hybrid" data-category="hybrid">
# <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_x0G5_Trainwreck-Hybrid-WM.jpg?width=160')"></div>
# <div class="isotope-body" style="background: url('https://cannabis.net/assets/app/img/hybrid.png?width=200'); background-size: cover;">
# <div class="element-item hybrid version2">
# <h3 class="name">Trainwreck</h3>
# <p class="symbol">Hy</p>
# <p class="number">Hybrid</p>
# <p class="thc"><b>THC - </b><span class="thc-data">12</span>-21%</p>
# <p class="cbd"><b>CBD - </b><span class="cbd-data">0.02</span>-0.1%</p>
# ...

# %%
images=soup.find_all('div',class_='isotope-image')
print(images)
# Out:
# [<div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_x0G5_Trainwreck-Hybrid-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_z75o_Blue-Dream-Hybrid-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3743_CB3y_Gorilla-Glue-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3743_WgT3_White-Widow-Hybrid-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_qWPQ_Agent-Orange-Hybrid-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_SnuP_AK-47-Hybrid-WM.jpg?width=160')"></div>, <div class="isotope-image" style="background-image: url('https://cannabis.net/drive/1000/3739_Pd3O_Cinderella-99-Hybrid-WM.jpg?width=1
# ...

# %%
browser.visit('https://disa.com/map-of-marijuana-legality-by-state/')  
cannabis_decrimes_url = "https://disa.com/map-of-marijuana-legality-by-state/"
table = pd.read_html(cannabis_decrimes_url)
df_decrimes=table[0]
df_decrimes
# Out:
#     0                                                  1
# 0 NaN  Sativa  Sativa is popular amongst smokers for ...
# 1 NaN  Indica  Indica is the chiller’s bud. Indica hi...
# 2 NaN  Hybrid  One of the wonderful things about the ...
